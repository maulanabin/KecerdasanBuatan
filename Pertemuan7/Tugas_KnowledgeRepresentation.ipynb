# %% [markdown]
# **Tugas**

# %%
# Maulana Bintang Irfansyah - TI 2H
rofi_and_setya_family = { 
    'Rofi': ['Anik', 'Lies', 'Fendi'],
    'Setya': ['Anik', 'Lies', 'Fendi'],
    'Didik': ['Lutfi', 'Andin'],
    'Anik': ['Lutfi', 'Andin'],
    'Lies': ['Hanan'],
    'Fendi': ['Lia', 'Vano'],
    'Ita': ['Lia', 'Vano'],
    'Lutfi': ['Farhan', 'Arfan'],
    'Andin': ['Naura']
}

def ancestors(genealogy, person):
  list_of_ancestors = []

  if person in genealogy:
    list_of_ancestors = genealogy[person]
    for e in genealogy[person]:
      for i in ancestors(genealogy, e):
        if i not in list_of_ancestors:
          list_of_ancestors += ancestors(genealogy, e)
  else:
    list_of_ancestors += []

  return list_of_ancestors

# 1st Printing
print('Hasil Representasi Pengetahuan Family Tree untuk anggota keluarga Ita:')
print (ancestors(rofi_and_setya_family, 'Ita'), '\n')

# 2nd Printing
print('Hasil Representasi Pengetahuan Family Tree untuk anggota keluarga Setya:')
print (ancestors(rofi_and_setya_family, 'Setya'), '\n')

# 3rd Printing
print('Hasil Representasi Pengetahuan Family Tree untuk anggota keluarga Irene:')
print (ancestors(rofi_and_setya_family, 'Irene'))
# Out:
# Hasil Representasi Pengetahuan Family Tree untuk anggota keluarga Ita:
# ['Lia', 'Vano']
#
# Hasil Representasi Pengetahuan Family Tree untuk anggota keluarga Setya:
# ['Anik', 'Lies', 'Fendi', 'Lutfi', 'Andin', 'Farhan', 'Arfan', 'Naura', 'Hanan', 'Lia', 'Vano']
#
# Hasil Representasi Pengetahuan Family Tree untuk anggota keluarga Irene:
# []
